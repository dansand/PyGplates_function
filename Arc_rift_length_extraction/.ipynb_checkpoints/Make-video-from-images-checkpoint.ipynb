# %%
import glob
import moviepy.editor as mpy
from moviepy.editor import *
from IPython.display import Image

# %%
#use glob to load all the images we need
frame_list = glob.glob('/Users/Andrew/Documents/PhD/Scripts/Gplates_Output/Prot_boundaries/COB/test_*.jpg')
#print frame_list
#frame_list.reverse()

# %%
clip = mpy.ImageSequenceClip(frame_list, fps=5) #turn them into a little movie
clip.write_videofile('COB_movie.mp4') #save output
# Out:
# [MoviePy] >>>> Building video COB_movie.mp4
# [MoviePy] Writing video COB_movie.mp4
# 100%|██████████| 100/100 [00:02<00:00, 42.08it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: COB_movie.mp4

# %%
clip = VideoFileClip('COB_movie.mp4')
ipython_display(clip, height=400)
# Out:
#  99%|█████████▉| 100/101 [00:00<00:00, 269.44it/s]
# <div align=middle><video height='400'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
